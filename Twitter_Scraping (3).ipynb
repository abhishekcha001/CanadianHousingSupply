# %%
! pip install pandas
! pip install ntscraper  # Replace with the correct package name if different

# %%
import pandas as pd
from ntscraper import Nitter

# %%
scraper = Nitter()
# Out:
# Testing instances: 100%|██████████| 33/33 [00:57<00:00,  1.75s/it]

# %%
def get_tweets (name, modes, no):
    tweets = scraper.get_tweets(name,mode = modes, number=no)
    final_tweets = []
    for tweet in tweets['tweets']:
        data = [tweet['link'], tweet['text'], tweet['date'], tweet['stats']['likes'], tweet['stats']['comments']]
        final_tweets.append(data)
    data = pd.DataFrame(final_tweets, columns =['link', 'text', 'date', 'No_of_Likes', 'No_of_retweets'])
    return data

# %%
data = get_tweets('Canadian housing rental price','term',5000)
# Out:
# INFO:root:No instance specified, using random instance https://nitter.moomoo.me
# INFO:root:Current stats for Canadian housing rental price: 19 tweets, 0 threads...
# INFO:root:Current stats for Canadian housing rental price: 32 tweets, 0 threads...
# INFO:root:Current stats for Canadian housing rental price: 44 tweets, 0 threads...
# INFO:root:Current stats for Canadian housing rental price: 47 tweets, 0 threads...

# %%
data
# Out:
#                                                  link  \
# 0   https://twitter.com/LabergeIvan/status/1725974...
# 1   https://twitter.com/HeavyliesCrown1/status/171...
# 2   https://twitter.com/deerpointmacro/status/1706...
# 3   https://twitter.com/SeanRos26250158/status/170...
# 4   https://twitter.com/Stephmking32/status/170139...
# 5   https://twitter.com/SmithersCND/status/1693297...
# 6   https://twitter.com/nettie_freddie/status/1693...
# 7   https://twitter.com/social_bravado/status/1692...
# 8   https://twitter.com/letsgobattIe/status/168905...
# 9   https://twitter.com/GregGuzik_Law/status/16861...
# 10  https://twitter.com/sprudames4000/status/16815...
# 11  https://twitter.com/OttawaMission/status/16810...
# 12  https://twitter.com/VAKanani/status/1679521386...
# 13  https://twitter.com/GregorCraigie/status/16795...
# 14  https://twitter.com/ElCanaco/status/1668032895...
# 15  https://twitter.com/paulgriffin1962/status/164...
# ...

# %%
data.to_csv('Canadian housing rental price.csv')

# %% [markdown]
# # New Section
